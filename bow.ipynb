# %%
import re

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from scipy.sparse import csr_matrix
from word_processing import Lemmatizer

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')

# %%
df = pd.read_csv("../data/cleaned.csv")

# %%
df.head()

# %%
# # Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=3001)

# # Fit the vectorizer and transform the cleaned text
X = vectorizer.fit_transform(df['text'])

# # Get the feature names to understand what words are included
feature_names = vectorizer.get_feature_names_out()

exclude_indices = [i for i, word in enumerate(feature_names) if word in ['reuters']]
X = csr_matrix(np.delete(X.toarray(), exclude_indices, axis=1))

# %%
y = np.where(df['Type'] == 'Fake', 0, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)

# %% [markdown]
# ## Testing accuracy

# %%
# Check accuracy on the test set
accuracy = svm_classifier.score(X_test, y_test)
print(f"Accuracy: {accuracy:.2%}")

# Predict the labels for the test set
y_pred = svm_classifier.predict(X_test)

# Generate a classification report
report = classification_report(y_test, y_pred, target_names=['Fake', 'Real'])
print(report)

# Print confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 97.87%
#               precision    recall  f1-score   support
#
#         Fake       0.97      0.98      0.98      4733
#         Real       0.98      0.97      0.98      4247
#
#     accuracy                           0.98      8980
#    macro avg       0.98      0.98      0.98      8980
# weighted avg       0.98      0.98      0.98      8980
#
# Confusion Matrix:
#  [[4662   71]
#  [ 120 4127]]

# %% [markdown]
# ## Training accuracy

# %%
# Check accuracy on the test set
test_accuracy = svm_classifier.score(X_train, y_train)
print(f"Accuracy: {test_accuracy:.2%}")

# Predict the labels for the test set
y_pred = svm_classifier.predict(X_train)

# Generate a classification report
report = classification_report(y_train, y_pred, target_names=['Fake', 'Real'])
print(report)

# Print confusion matrix
conf_matrix = confusion_matrix(y_train, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 100.00%
#               precision    recall  f1-score   support
#
#         Fake       1.00      1.00      1.00     18748
#         Real       1.00      1.00      1.00     17170
#
#     accuracy                           1.00     35918
#    macro avg       1.00      1.00      1.00     35918
# weighted avg       1.00      1.00      1.00     35918
#
# Confusion Matrix:
#  [[18748     0]
#  [    1 17169]]

# %%
coefficients = svm_classifier.coef_.toarray().flatten()  # Flatten to a 1D array for easier access
# Sort the coefficients by their absolute values
top_indices = np.argsort(coefficients)[50:]  # Get the indices of the top 10 words

# Get the corresponding words (features) for those top indices
top_words = feature_names[top_indices]

# Get the corresponding coefficients (weights) for those words
top_weights = coefficients[top_indices]

# Display the top words and their corresponding weights
for word, weight in zip(top_words, top_weights):
    print(f"Word: {word}, Weight: {weight}")
# Out:
# Word: friend, Weight: -0.5916580191364373
# Word: taxpayer, Weight: -0.5870444857895719
# Word: didn, Weight: -0.5841330387074372
# Word: foster, Weight: -0.584016414395181
# Word: chaos, Weight: -0.5792751418078012
# Word: train, Weight: -0.5754901485731667
# Word: campus, Weight: -0.5738164824920291
# Word: oh, Weight: -0.5654337141088184
# Word: massive, Weight: -0.5610873818830896
# Word: gonna, Weight: -0.5584000796385048
# Word: washington, Weight: -0.5578841859825592
# Word: ed, Weight: -0.5525509133168657
# Word: disaster, Weight: -0.5489486542104971
# Word: pointed, Weight: -0.5486957553798677
# Word: requested, Weight: -0.5462854775404125
# Word: funded, Weight: -0.5432733116316673
# Word: state, Weight: -0.5431598181392745
# Word: removed, Weight: -0.5412970795654108
# Word: crazy, Weight: -0.5407760537169036
# Word: reached, Weight: -0.5381058318549405
# Word: roy, Weight: -0.5341309829607584
# Word: offensive, Weight: -0.5334827219564013
# Word: suggests, Weight: -0.5328915683480057
# Word: aggressive, Weight: -0.529997000908886
# Word: gov, Weight: -0.5272592213251979
# Word: doesn, Weight: -0.5229604861212641
# Word: involved, Weight: -0.5194015582929925
# Word: destroy, Weight: -0.5148866050316495
# Word: surprised, Weight: -0.5122299074208894
# Word: lady, Weight: -0.5115089392761634
# Word: irs, Weight: -0.5114285932747773
# Word: controversial, Weight: -0.5112438936578021
# Word: typically, Weight: -0.5110108505178635
# Word: exit, Weight: -0.5091868823680702
# Word: performance, Weight: -0.5035454358554378
# Word: instead, Weight: -0.5034295694212745
# Word: religion, Weight: -0.4998070256136201
# Word: hosted, Weight: -0.4976979684872671
# Word: reason, Weight: -0.4968675136607217
# Word: afternoon, Weight: -0.49634731313052866
# Word: pool, Weight: -0.4960039961588112
# Word: traditional, Weight: -0.4944677325139758
# Word: replacement, Weight: -0.49275407125227666
# Word: ford, Weight: -0.4923642009606405
# Word: coming, Weight: -0.49043450106403774
# Word: noted, Weight: -0.48975500824535656
# Word: standing, Weight: -0.487285563282345
# Word: understand, Weight: -0.48596919829834784
# Word: founder, Weight: -0.4817407414174294
# Word: hired, Weight: -0.4816502621441599
# Word: learned, Weight: -0.4803618794916434
# Word: aliens, Weight: -0.4785822570896969
# Word: finally, Weight: -0.4772717467151796
# Word: arms, Weight: -0.4764063151250093
# Word: hit, Weight: -0.4701860734486898
# Word: just, Weight: -0.46932159427918496
# Word: primary, Weight: -0.466340059004035
# Word: aren, Weight: -0.466282478700637
# Word: attempting, Weight: -0.4657874711354334
# Word: using, Weight: -0.4656230565338534
# Word: scott, Weight: -0.46560572687508917
# Word: version, Weight: -0.46526065262539634
# Word: demands, Weight: -0.46334378799837717
# Word: afford, Weight: -0.46169633699665585
# Word: warned, Weight: -0.4612446493265318
# Word: probably, Weight: -0.4607866424227658
# Word: hillary, Weight: -0.4570216727818017
# Word: clintons, Weight: -0.45591530772486655
# Word: war, Weight: -0.4535168079298052
# Word: chose, Weight: -0.452819829982901
# Word: flickr, Weight: -0.4513996644126582
# Word: covered, Weight: -0.4497677594165967
# Word: folks, Weight: -0.4484839965023091
# Word: extra, Weight: -0.4477478784239845
# Word: veterans, Weight: -0.4455580589803276
# Word: cops, Weight: -0.44367655088622143
# Word: unusual, Weight: -0.44353458293571607
# Word: hot, Weight: -0.4408592098705665
# Word: numerous, Weight: -0.44019490146285734
# Word: university, Weight: -0.439936737532853
# Word: ll, Weight: -0.4353021893297156
# Word: west, Weight: -0.43511738881064993
# Word: played, Weight: -0.4350172416853114
# Word: author, Weight: -0.43290682833580807
# Word: united, Weight: -0.4325761894879896
# Word: loss, Weight: -0.43252088477415956
# Word: matter, Weight: -0.4324734875880238
# Word: press, Weight: -0.43071775238020815
# Word: fair, Weight: -0.4274922336185363
# Word: announced, Weight: -0.42707352733355286
# Word: post, Weight: -0.42640423561205704
# Word: offer, Weight: -0.4255849512150133
# Word: guys, Weight: -0.42473768332419554
# Word: identified, Weight: -0.423948398276918
# Word: arizona, Weight: -0.42343175878025907
# Word: figure, Weight: -0.4205560361305418
# Word: js, Weight: -0.41938085006191367
# Word: position, Weight: -0.41831107150603825
# Word: pelosi, Weight: -0.41756946534882877
# Word: maybe, Weight: -0.4173644450953003
# Word: diplomats, Weight: -0.41508899358598095
# Word: certainly, Weight: -0.41309183447900133
# Word: hosts, Weight: -0.41203036745117066
# Word: undocumented, Weight: -0.4118924510392876
# Word: heavy, Weight: -0.4115712554137274
# Word: reid, Weight: -0.40907437104545485
# Word: moment, Weight: -0.4088895038694765
# Word: bernie, Weight: -0.40610147716740475
# Word: 37, Weight: -0.4056593534217294
# Word: voted, Weight: -0.40415478767286556
# Word: terrorists, Weight: -0.403696016809203
# Word: demanded, Weight: -0.40133173277899026
# Word: began, Weight: -0.40061552487686225
# Word: flags, Weight: -0.40055034681244023
# Word: historic, Weight: -0.40039526568060263
# Word: proud, Weight: -0.3999604448064854
# Word: mental, Weight: -0.39963739158034634
# Word: yes, Weight: -0.398064677293849
# Word: incident, Weight: -0.39737657114449076
# Word: obtained, Weight: -0.39506657367338105
# Word: failed, Weight: -0.3934221143485396
# Word: chip, Weight: -0.39215075613446365
# Word: opening, Weight: -0.39142201862025405
# Word: caller, Weight: -0.39125372246152446
# Word: idea, Weight: -0.39117185202696625
# Word: faith, Weight: -0.39095955753207323
# Word: continues, Weight: -0.3906025419566611
# Word: la, Weight: -0.38939200989210515
# Word: carbon, Weight: -0.3883494763612678
# Word: connected, Weight: -0.38641533558514
# Word: powers, Weight: -0.3858569011713812
# Word: page, Weight: -0.3858341692287618
# Word: chair, Weight: -0.385624053184214
# Word: affect, Weight: -0.3848300790551067
# Word: justices, Weight: -0.38361724276035564
# Word: ice, Weight: -0.38326885276642353
# Word: door, Weight: -0.38236698789257384
# Word: politically, Weight: -0.38228007864220226
# Word: attacking, Weight: -0.3820754980149789
# Word: sure, Weight: -0.38144213309419606
# Word: supremacists, Weight: -0.3761453427264211
# Word: plans, Weight: -0.3743623138193489
# Word: bigger, Weight: -0.37430155356332806
# Word: brian, Weight: -0.3733160649654597
# Word: express, Weight: -0.3731500149919103
# Word: claimed, Weight: -0.37311429981039185
# Word: scene, Weight: -0.3722477316401052
# Word: unclear, Weight: -0.37019419260950265
# Word: fox, Weight: -0.3683509799914866
# Word: doing, Weight: -0.3676917782322941
# Word: victims, Weight: -0.36752166254737484
# Word: obviously, Weight: -0.3672217322867968
# Word: embarrassing, Weight: -0.36697060264871956
# Word: mass, Weight: -0.36678760287622114
# Word: newly, Weight: -0.36480781721965827
# Word: events, Weight: -0.36410600440122376
# Word: considered, Weight: -0.3638200487691665
# Word: range, Weight: -0.3636199663966698
# Word: fit, Weight: -0.3618716544128533
# Word: listen, Weight: -0.3610542423717584
# Word: oval, Weight: -0.36041585542425003
# Word: dr, Weight: -0.3598356269276102
# Word: meaning, Weight: -0.3592600023249659
# Word: 25, Weight: -0.3590405752773491
# Word: steps, Weight: -0.3576724330232212
# Word: present, Weight: -0.3574921275916194
# Word: reuters, Weight: -0.356816218391928
# Word: victory, Weight: -0.3558948885336115
# Word: weeks, Weight: -0.35430062510672367
# Word: keeps, Weight: -0.35305996891259495
# Word: simply, Weight: -0.35282795932322497
# Word: die, Weight: -0.34998878899077684
# Word: reaching, Weight: -0.3493927922584381
# Word: demand, Weight: -0.3491003329169458
# Word: civilians, Weight: -0.3486077900013336
# Word: really, Weight: -0.3473404055052554
# Word: begun, Weight: -0.3472920752080303
# Word: possibly, Weight: -0.34639331334950835
# Word: went, Weight: -0.34577370866261475
# Word: operation, Weight: -0.3453930040189116
# Word: opinion, Weight: -0.34178592307591393
# Word: addition, Weight: -0.34105203333910683
# Word: presidents, Weight: -0.341004328216059
# Word: debates, Weight: -0.3401652112342891
# Word: sick, Weight: -0.3394540055737837
# Word: american, Weight: -0.3378422394678933
# Word: common, Weight: -0.33706493590353026
# Word: refused, Weight: -0.335820418134919
# Word: phone, Weight: -0.3349977231765853
# Word: thank, Weight: -0.3324661872457644
# Word: stopped, Weight: -0.3319671632488814
# Word: planned, Weight: -0.3319449151278786
# Word: text, Weight: -0.3306298986331536
# Word: pentagon, Weight: -0.3301860601106318
# Word: ultimately, Weight: -0.33013040335320826
# Word: tweets, Weight: -0.32929615516592187
# Word: speaking, Weight: -0.32889911020123963
# Word: check, Weight: -0.32838222424841745
# Word: oversight, Weight: -0.32810563852903923
# Word: hollywood, Weight: -0.3278070508924901
# Word: consumer, Weight: -0.3271428328142783
# Word: relief, Weight: -0.3271158778614121
# Word: kill, Weight: -0.3269859542208691
# Word: thursday, Weight: -0.32692545499389325
# Word: blaming, Weight: -0.3266333153753298
# Word: protections, Weight: -0.32584791496512844
# Word: racist, Weight: -0.3256245850102183
# Word: study, Weight: -0.3248934145427153
# Word: camera, Weight: -0.32429942463970374
# Word: xi, Weight: -0.32404601716519127
# Word: removal, Weight: -0.3240431934741244
# Word: refusing, Weight: -0.32308052442438456
# Word: provided, Weight: -0.3229299843290747
# Word: leftist, Weight: -0.3210917860659719
# Word: 50, Weight: -0.31830372382026606
# Word: discrimination, Weight: -0.3182728608993254
# Word: flynn, Weight: -0.3178071003929357
# Word: ross, Weight: -0.31776308225049976
# Word: employee, Weight: -0.3172564639749383
# Word: female, Weight: -0.3172227742195048
# Word: refugee, Weight: -0.3167749117791645
# Word: owner, Weight: -0.3163221927928118
# Word: georgia, Weight: -0.31612142071407084
# Word: decisions, Weight: -0.3158296023362702
# Word: isis, Weight: -0.3151823871240049
# Word: decide, Weight: -0.31370128566827954
# Word: chance, Weight: -0.31322930959053086
# Word: attended, Weight: -0.31319547389589625
# Word: sexually, Weight: -0.31288139232777545
# Word: citizen, Weight: -0.3126213937501962
# Word: officer, Weight: -0.3120673390405183
# Word: baltimore, Weight: -0.31204484720705306
# Word: table, Weight: -0.3117011924228007
# Word: benghazi, Weight: -0.31108911548717927
# Word: attention, Weight: -0.3107698719848232
# Word: sit, Weight: -0.30988138454847086
# Word: promoting, Weight: -0.3096101630683026
# Word: accountable, Weight: -0.3094370406499779
# Word: findings, Weight: -0.3091164928350656
# Word: obama, Weight: -0.3090803745942172
# Word: stance, Weight: -0.30901170907306474
# Word: participate, Weight: -0.3076399794681189
# Word: shooting, Weight: -0.3068865727891736
# Word: course, Weight: -0.30672399333439343
# Word: players, Weight: -0.3061113625403519
# Word: liberals, Weight: -0.306000553814934
# Word: wife, Weight: -0.3052120336976587
# Word: county, Weight: -0.3048344540570326
# Word: racism, Weight: -0.3042654052783488
# Word: ok, Weight: -0.3032421026563143
# Word: networks, Weight: -0.30249510652686773
# Word: lied, Weight: -0.302347195584186
# Word: crime, Weight: -0.30230787690520955
# Word: happening, Weight: -0.3018471827911907
# Word: specific, Weight: -0.30120564836655617
# Word: kremlin, Weight: -0.30112541322454245
# Word: extremely, Weight: -0.30035928262872547
# Word: services, Weight: -0.2993477223860044
# Word: trail, Weight: -0.29908974471710126
# Word: streets, Weight: -0.2989000365616651
# Word: expect, Weight: -0.29853309153118324
# Word: says, Weight: -0.298387112345381
# Word: terrible, Weight: -0.2975136849430882
# Word: resort, Weight: -0.2965051018848652
# Word: collusion, Weight: -0.29637062162605643
# Word: raqqa, Weight: -0.29599933957220953
# Word: mayor, Weight: -0.2957870488297527
# Word: encourage, Weight: -0.29559628847635494
# Word: nation, Weight: -0.2953317205615414
# Word: susan, Weight: -0.2950663117010336
# Word: option, Weight: -0.2949811245724949
# Word: break, Weight: -0.2947034979701014
# Word: violence, Weight: -0.2945287570374335
# Word: sharing, Weight: -0.29396997345902953
# Word: riyadh, Weight: -0.2937311836216605
# Word: alex, Weight: -0.29350534464480876
# Word: bloomberg, Weight: -0.2929407895834867
# Word: nunes, Weight: -0.2928629519237115
# Word: 12, Weight: -0.29265880479680945
# Word: cnn, Weight: -0.29244827319816635
# Word: sunday, Weight: -0.2922598874444564
# Word: india, Weight: -0.2918573842729703
# Word: shut, Weight: -0.2915563027337159
# Word: practices, Weight: -0.29152118750383144
# Word: pretty, Weight: -0.2914147347077813
# Word: elite, Weight: -0.2903676975669037
# Word: interviews, Weight: -0.2901685687068279
# Word: joseph, Weight: -0.29007511611959547
# Word: mistake, Weight: -0.28987586946589927
# Word: language, Weight: -0.2895866827497281
# Word: thousands, Weight: -0.2893090035521433
# Word: creating, Weight: -0.28922705637633955
# Word: proven, Weight: -0.2883229350176894
# Word: ticket, Weight: -0.2880592157746063
# Word: interviewed, Weight: -0.2874706252120366
# Word: contact, Weight: -0.2872022111050517
# Word: jeff, Weight: -0.28720065960482266
# Word: won, Weight: -0.28624223644320484
# Word: employees, Weight: -0.28604163504996083
# Word: flint, Weight: -0.2858836600065454
# Word: suspended, Weight: -0.28573537255504283
# Word: suffering, Weight: -0.2850444993857747
# Word: struggle, Weight: -0.2845770509761629
# Word: sued, Weight: -0.2841859395958005
# Word: attorneys, Weight: -0.2841503438933189
# Word: david, Weight: -0.2839521942615859
# Word: alleged, Weight: -0.2837632871572594
# Word: concluded, Weight: -0.2832865582438428
# Word: partisan, Weight: -0.28324051513737847
# Word: danger, Weight: -0.2832095526068776
# Word: presidency, Weight: -0.2829673278775578
# Word: believed, Weight: -0.2827044225011256
# Word: muslim, Weight: -0.28258163483705456
# Word: male, Weight: -0.2821693795026536
# Word: harm, Weight: -0.28191196386879086
# Word: recently, Weight: -0.2814790048496367
# Word: prison, Weight: -0.280973172324854
# Word: unlike, Weight: -0.2808788893333531
# Word: represents, Weight: -0.2806151226990915
# Word: williams, Weight: -0.28058573105219253
# Word: attempt, Weight: -0.2802452948051679
# Word: khan, Weight: -0.27959759115348715
# Word: black, Weight: -0.2795096481880781
# Word: soros, Weight: -0.27942779389756833
# Word: virginia, Weight: -0.2792425206324672
# Word: uses, Weight: -0.27879535037740477
# Word: mcconnell, Weight: -0.2783728510956909
# Word: word, Weight: -0.2780817565717402
# Word: publicly, Weight: -0.2777095807316725
# Word: documents, Weight: -0.27727191518516814
# Word: claim, Weight: -0.27661322111911935
# Word: refuse, Weight: -0.2762472543253256
# Word: chinese, Weight: -0.27568214645185296
# Word: cost, Weight: -0.27566508951658064
# Word: average, Weight: -0.2749616236780734
# Word: reasons, Weight: -0.2738779177581748
# Word: quick, Weight: -0.2734674260682125
# Word: code, Weight: -0.27247440565669406
# Word: 2010, Weight: -0.272371237913212
# Word: billionaire, Weight: -0.2723583094688634
# Word: apparent, Weight: -0.27216595816758915
# Word: deep, Weight: -0.2721273896719883
# Word: doj, Weight: -0.2721098129519433
# Word: christian, Weight: -0.2715692271201321
# Word: prevent, Weight: -0.27139086392025524
# Word: followers, Weight: -0.2712717159699484
# Word: avoid, Weight: -0.2700677366873406
# Word: environmental, Weight: -0.27001283552313887
# Word: forget, Weight: -0.26993617200162384
# Word: jail, Weight: -0.2693002605570911
# Word: benefits, Weight: -0.26833857957797647
# Word: victim, Weight: -0.2669942345491763
# Word: internet, Weight: -0.2664925697390185
# Word: forward, Weight: -0.2661927668806029
# Word: okay, Weight: -0.2658871721075713
# Word: leaks, Weight: -0.26498107145907523
# Word: sanctions, Weight: -0.2649654933016392
# Word: importance, Weight: -0.2647934174560624
# Word: professor, Weight: -0.26472707590964284
# Word: endorsed, Weight: -0.26448376460502643
# Word: cultural, Weight: -0.2644533485178776
# Word: circuit, Weight: -0.2639879676798891
# Word: currently, Weight: -0.26283410772868876
# Word: aside, Weight: -0.26278094655073353
# Word: intention, Weight: -0.2627789800148459
# Word: lies, Weight: -0.26182828482188136
# Word: learn, Weight: -0.2609507356749104
# Word: times, Weight: -0.260923351940426
# Word: dnc, Weight: -0.26028054565169967
# Word: commitment, Weight: -0.26023181446009513
# Word: vegas, Weight: -0.26012071530803216
# Word: equal, Weight: -0.2599985109739393
# Word: exactly, Weight: -0.2588993216111084
# Word: support, Weight: -0.25818966722738723
# Word: beliefs, Weight: -0.25793383780124585
# Word: urging, Weight: -0.2574968256640505
# Word: brown, Weight: -0.257494929137409
# Word: europe, Weight: -0.25709447364850857
# Word: building, Weight: -0.25685738609795017
# Word: responded, Weight: -0.256761715683846
# Word: leading, Weight: -0.2567043356683532
# Word: boy, Weight: -0.25645970816110153
# Word: sensitive, Weight: -0.2562722660545145
# Word: paul, Weight: -0.25606659922889524
# Word: paper, Weight: -0.2558156964736947
# Word: theresa, Weight: -0.25576941468959624
# Word: sales, Weight: -0.25563915097575673
# Word: native, Weight: -0.2553775381032351
# Word: outrage, Weight: -0.25522311174029766
# Word: arrived, Weight: -0.25390636462826516
# Word: originally, Weight: -0.2538156467203446
# Word: ivanka, Weight: -0.25300716717919225
# Word: desire, Weight: -0.25240703249860064
# Word: condition, Weight: -0.251480706721777
# Word: limits, Weight: -0.25146670298036433
# Word: moderate, Weight: -0.2509532539387807
# Word: single, Weight: -0.25074366433999573
# Word: split, Weight: -0.24997829561475582
# Word: shows, Weight: -0.24918146994108614
# Word: podesta, Weight: -0.2481072326428629
# Word: situation, Weight: -0.24809089883730154
# Word: causing, Weight: -0.24800507695099394
# Word: ass, Weight: -0.24739022099739086
# Word: delegates, Weight: -0.24738942750834267
# Word: fall, Weight: -0.24724350452145147
# Word: report, Weight: -0.24688440882896548
# Word: utah, Weight: -0.24668250925356983
# Word: past, Weight: -0.24645421849657684
# Word: chances, Weight: -0.24642157668709072
# Word: amnesty, Weight: -0.24618776148262667
# Word: wire, Weight: -0.24562654857102384
# Word: actually, Weight: -0.24476716381353586
# Word: stephen, Weight: -0.24420336286946287
# Word: acts, Weight: -0.2433955669134976
# Word: continued, Weight: -0.24314488417607844
# Word: add, Weight: -0.241927017828388
# Word: legally, Weight: -0.2418541587721697
# Word: hearing, Weight: -0.24128314009540558
# Word: worst, Weight: -0.24076549012658213
# Word: interested, Weight: -0.24060560612382836
# Word: highest, Weight: -0.2405557947867221
# Word: number, Weight: -0.24002738283822514
# Word: keeping, Weight: -0.2394614446784463
# Word: rising, Weight: -0.23932080225357633
# Word: hacked, Weight: -0.23775548581425746
# Word: listed, Weight: -0.23650662699085395
# Word: immigrants, Weight: -0.23637783136131704
# Word: sentence, Weight: -0.23577769572900656
# Word: rebels, Weight: -0.23573223073211746
# Word: rest, Weight: -0.2356651270191881
# Word: congressman, Weight: -0.2351027327142062
# Word: prime, Weight: -0.2346401407733589
# Word: note, Weight: -0.23441871000171124
# Word: park, Weight: -0.23438835051085363
# Word: kingdom, Weight: -0.23359363256731408
# Word: reaction, Weight: -0.2334003512619686
# Word: gone, Weight: -0.2332630016499338
# Word: counter, Weight: -0.2330924734762443
# Word: realdonaldtrump, Weight: -0.2323363216937665
# Word: hasn, Weight: -0.23172462514037565
# Word: little, Weight: -0.2315607958160085
# Word: intent, Weight: -0.23139666545332493
# Word: taiwan, Weight: -0.23130187503772096
# Word: 15, Weight: -0.231293941166458
# Word: bringing, Weight: -0.23082416418246018
# Word: moving, Weight: -0.2308132966836565
# Word: lack, Weight: -0.23033160412782241
# Word: integrity, Weight: -0.22986298406224864
# Word: left, Weight: -0.22982184332782873
# Word: hurt, Weight: -0.2293801326434978
# Word: screen, Weight: -0.22937539818006658
# Word: direct, Weight: -0.22901796284049505
# Word: criminal, Weight: -0.2287217238890401
# Word: iran, Weight: -0.2286233784615952
# Word: hate, Weight: -0.22774681389165927
# Word: missile, Weight: -0.22761297421971424
# Word: evil, Weight: -0.22755096221193183
# Word: russian, Weight: -0.2265879525453934
# Word: soon, Weight: -0.22658670986496593
# Word: problem, Weight: -0.2265604467817
# Word: argument, Weight: -0.2264954269167234
# Word: rally, Weight: -0.2263298049145151
# Word: headed, Weight: -0.2254402832314132
# Word: mandate, Weight: -0.22498463495890839
# Word: propaganda, Weight: -0.2249142007287817
# Word: graham, Weight: -0.22465807690494302
# Word: step, Weight: -0.224383945283243
# Word: reporter, Weight: -0.22420181042515458
# Word: raised, Weight: -0.2241970969957995
# Word: clip, Weight: -0.22395221138566224
# Word: anti, Weight: -0.22387697587104458
# Word: angeles, Weight: -0.22380160592821408
# Word: epa, Weight: -0.22265008505336695
# Word: receive, Weight: -0.22247541230602075
# Word: guy, Weight: -0.221886963779938
# Word: dhs, Weight: -0.2218400239840724
# Word: condemned, Weight: -0.22183621879411553
# Word: brothers, Weight: -0.2213060234121285
# Word: reject, Weight: -0.22127865401122432
# Word: clearly, Weight: -0.22118951587326796
# Word: ran, Weight: -0.22052584110931847
# Word: entered, Weight: -0.21941472522793043
# Word: issues, Weight: -0.21930181899948245
# Word: committees, Weight: -0.21921694268998942
# Word: haven, Weight: -0.2186923416190195
# Word: operations, Weight: -0.21856643085656247
# Word: blamed, Weight: -0.21845213730074814
# Word: puts, Weight: -0.2183120641894088
# Word: smith, Weight: -0.21794732126995392
# Word: september, Weight: -0.21736498076053037
# Word: property, Weight: -0.2169167423847682
# Word: quality, Weight: -0.21674245773275314
# Word: investigations, Weight: -0.21666069633458598
# Word: floor, Weight: -0.21652339583596925
# Word: definitely, Weight: -0.21637032850832752
# Word: basically, Weight: -0.21635360338011944
# Word: particular, Weight: -0.21601581273628406
# Word: carson, Weight: -0.2158187673540398
# Word: married, Weight: -0.21541058589336604
# Word: natural, Weight: -0.21404715107093442
# Word: open, Weight: -0.21397400168321473
# Word: needs, Weight: -0.21383015562250532
# Word: nra, Weight: -0.2135070533537346
# Word: false, Weight: -0.2131430278146907
# Word: stand, Weight: -0.21302538682315775
# Word: ads, Weight: -0.21273973290976092
# Word: defended, Weight: -0.21249478278628336
# Word: points, Weight: -0.21213209826603655
# Word: cruz, Weight: -0.21202182604119887
# Word: television, Weight: -0.21174408413287366
# Word: paid, Weight: -0.21159896750838855
# Word: caught, Weight: -0.21137983073559927
# Word: isn, Weight: -0.21024467112066603
# Word: girls, Weight: -0.20981311171920713
# Word: putting, Weight: -0.2095066064564349
# Word: federal, Weight: -0.20895273341328613
# Word: disturbing, Weight: -0.2083308022543097
# Word: capture, Weight: -0.20830562089955879
# Word: 2013, Weight: -0.20822691469676874
# Word: daca, Weight: -0.20809823875889266
# Word: undermine, Weight: -0.20783728044944766
# Word: defend, Weight: -0.20777289917393618
# Word: refugees, Weight: -0.20707075012345041
# Word: flight, Weight: -0.2069371223526827
# Word: appointed, Weight: -0.2066151196995558
# Word: rare, Weight: -0.2065610697061745
# Word: couldn, Weight: -0.20621953803748527
# Word: threats, Weight: -0.20603775614084485
# Word: kid, Weight: -0.20578248525890205
# Word: rebel, Weight: -0.20570597512158215
# Word: changing, Weight: -0.20568910660697232
# Word: harvard, Weight: -0.20534478412907425
# Word: pennsylvania, Weight: -0.20508252188115833
# Word: armed, Weight: -0.20449090649377488
# Word: tried, Weight: -0.20445042806561942
# Word: july, Weight: -0.20442845669269583
# Word: physical, Weight: -0.20440113197800344
# Word: award, Weight: -0.20436495884464786
# Word: service, Weight: -0.2038684366441546
# Word: regime, Weight: -0.2033226142879931
# Word: veteran, Weight: -0.2027522779996768
# Word: endorse, Weight: -0.2027374300982685
# Word: brexit, Weight: -0.20211940639150316
# Word: attacked, Weight: -0.2020426294028631
# Word: discussions, Weight: -0.20202338751229465
# Word: predecessor, Weight: -0.2017758020722145
# Word: youtube, Weight: -0.20175716211797656
# Word: received, Weight: -0.20125248505231713
# Word: bias, Weight: -0.2012145081966982
# Word: attorney, Weight: -0.19995086786831406
# Word: reports, Weight: -0.19947792524462649
# Word: putin, Weight: -0.1993228601267441
# Word: terrorism, Weight: -0.19870057922250106
# Word: sachs, Weight: -0.198326484107666
# Word: described, Weight: -0.19815208434075107
# Word: meet, Weight: -0.19791574806318363
# Word: grant, Weight: -0.19788835151880743
# Word: sea, Weight: -0.19775837899341983
# Word: agenda, Weight: -0.19729330647063045
# Word: lives, Weight: -0.19718895862404395
# Word: shocking, Weight: -0.19701079594951204
# Word: registered, Weight: -0.19686547364620638
# Word: initially, Weight: -0.1968324316504888
# Word: server, Weight: -0.1966501959316281
# Word: stay, Weight: -0.19640892941247928
# Word: cut, Weight: -0.19628888631621788
# Word: funny, Weight: -0.1962776370521605
# Word: kind, Weight: -0.19611245505503216
# Word: series, Weight: -0.19593657049801141
# Word: weapons, Weight: -0.19565298945777493
# Word: october, Weight: -0.19540490022664378
# Word: opportunity, Weight: -0.19516321764508315
# Word: exist, Weight: -0.19495931410201403
# Word: shortly, Weight: -0.19370065524665273
# Word: detroit, Weight: -0.19362056632731817
# Word: small, Weight: -0.19360626473785117
# Word: bashar, Weight: -0.19317017396939926
# Word: blacks, Weight: -0.19296338670821264
# Word: affordable, Weight: -0.19272613565900476
# Word: felt, Weight: -0.19262500076151307
# Word: controversy, Weight: -0.19245453400335047
# Word: circumstances, Weight: -0.19198323558681535
# Word: announcement, Weight: -0.19170993266590639
# Word: carry, Weight: -0.19128717068175533
# Word: fact, Weight: -0.19093440246637905
# Word: bin, Weight: -0.19056562196667
# Word: corrupt, Weight: -0.19017963417287936
# Word: terrorist, Weight: -0.19000997231897587
# Word: feeling, Weight: -0.18961773517646183
# Word: research, Weight: -0.1895647046755474
# Word: having, Weight: -0.18945526109120753
# Word: thomas, Weight: -0.1893301597007522
# Word: case, Weight: -0.18921677702793593
# Word: card, Weight: -0.18916846317312047
# Word: ruling, Weight: -0.1890579986473568
# Word: violations, Weight: -0.1888534832532788
# Word: kids, Weight: -0.18839465022369725
# Word: apple, Weight: -0.18780824393315007
# Word: sought, Weight: -0.1874735872021433
# Word: christmas, Weight: -0.18697060140316504
# Word: trust, Weight: -0.1868947289217545
# Word: vice, Weight: -0.18688795955836984
# Word: 2003, Weight: -0.1868352902545693
# Word: blame, Weight: -0.18664469267172165
# Word: senator, Weight: -0.18654194727258344
# Word: politicians, Weight: -0.18650941403619342
# Word: record, Weight: -0.1861599404554622
# Word: wing, Weight: -0.18613376056204226
# Word: mrs, Weight: -0.18588216202608646
# Word: helping, Weight: -0.1858142631627455
# Word: amendment, Weight: -0.18562528850506738
# Word: key, Weight: -0.18541202492696868
# Word: fun, Weight: -0.18535386907400747
# Word: 29, Weight: -0.18513720697546593
# Word: plane, Weight: -0.18492419114894382
# Word: americans, Weight: -0.18481466506035793
# Word: ban, Weight: -0.1842870710858682
# Word: february, Weight: -0.18414508896748902
# Word: mainstream, Weight: -0.18377734252776745
# Word: dollars, Weight: -0.18362887906670047
# Word: ve, Weight: -0.18323676767931968
# Word: caucus, Weight: -0.18238108277137086
# Word: mind, Weight: -0.18233959976596625
# Word: minorities, Weight: -0.18176182901518773
# Word: kevin, Weight: -0.18165351521385548
# Word: asylum, Weight: -0.18124853632914187
# Word: america, Weight: -0.18108508375277366
# Word: sessions, Weight: -0.18082901062899695
# Word: notice, Weight: -0.18052745172502027
# Word: biden, Weight: -0.18021721206412417
# Word: custody, Weight: -0.18012071925160159
# Word: appear, Weight: -0.18002820656936558
# Word: photos, Weight: -0.17986495196791297
# Word: reality, Weight: -0.17964133326251938
# Word: pyongyang, Weight: -0.17958183791743712
# Word: threatening, Weight: -0.1795254641462518
# Word: accusing, Weight: -0.17948949448670912
# Word: calls, Weight: -0.1794830897198293
# Word: women, Weight: -0.17929695348318386
# Word: 11, Weight: -0.17922512499869286
# Word: hateful, Weight: -0.17917611210721848
# Word: costs, Weight: -0.17865900239132768
# Word: id, Weight: -0.17838269371529827
# Word: requests, Weight: -0.17805444329436546
# Word: names, Weight: -0.1775690228265761
# Word: block, Weight: -0.17755234992239355
# Word: joke, Weight: -0.1771862674974814
# Word: hannity, Weight: -0.1771011209005509
# Word: member, Weight: -0.17699689957631862
# Word: associated, Weight: -0.17640231981462665
# Word: managed, Weight: -0.17604536239474114
# Word: iraqi, Weight: -0.17573682986912736
# Word: line, Weight: -0.1752120217725008
# Word: share, Weight: -0.17517492967940795
# Word: jones, Weight: -0.1742642825408403
# Word: push, Weight: -0.17370516131306368
# Word: remaining, Weight: -0.1736102138244635
# Word: beat, Weight: -0.17353223119814154
# Word: true, Weight: -0.17344184339408034
# Word: agent, Weight: -0.17230421441535337
# Word: millions, Weight: -0.17226016163497507
# Word: illegally, Weight: -0.17196445601026447
# Word: stupid, Weight: -0.17192490365743268
# Word: knew, Weight: -0.17191417176581697
# Word: sending, Weight: -0.17057011180391665
# Word: visas, Weight: -0.17035867263554505
# Word: matters, Weight: -0.17022259485304336
# Word: advocate, Weight: -0.17001730833762507
# Word: knows, Weight: -0.1699655763272737
# Word: feels, Weight: -0.16978775545140054
# Word: fraud, Weight: -0.16915788038354007
# Word: experts, Weight: -0.16891385093314323
# Word: caused, Weight: -0.1686751723038907
# Word: lived, Weight: -0.16866641477773853
# Word: free, Weight: -0.1684326717536383
# Word: spend, Weight: -0.16759913630614678
# Word: shares, Weight: -0.1674490840785013
# Word: assault, Weight: -0.16738589491109213
# Word: suggested, Weight: -0.16736661684317075
# Word: emails, Weight: -0.1672310544508656
# Word: effectively, Weight: -0.1669150074250607
# Word: violated, Weight: -0.16675486240551937
# Word: surveillance, Weight: -0.16666422956615648
# Word: pulled, Weight: -0.1662666884846754
# Word: youth, Weight: -0.16599752064763362
# Word: money, Weight: -0.16590314421938324
# Word: concerning, Weight: -0.16579155161158626
# Word: journalist, Weight: -0.1650668881211296
# Word: got, Weight: -0.1645663507868255
# Word: migrants, Weight: -0.16433507035823375
# Word: initiative, Weight: -0.16409529848809143
# Word: issued, Weight: -0.16402429946062885
# Word: behalf, Weight: -0.16369506128408456
# Word: hell, Weight: -0.16368127996182208
# Word: peaceful, Weight: -0.1633727088463534
# Word: girl, Weight: -0.16334843137156962
# Word: served, Weight: -0.16317688160666344
# Word: 100, Weight: -0.16313789394136413
# Word: lee, Weight: -0.16281109445310118
# Word: pointing, Weight: -0.1626904269545556
# Word: soldiers, Weight: -0.16266170593867163
# Word: high, Weight: -0.16261762833931176
# Word: moore, Weight: -0.16221902145629338
# Word: include, Weight: -0.16218060150262598
# Word: focus, Weight: -0.1619695651640204
# Word: criminals, Weight: -0.1619495470151341
# Word: divisive, Weight: -0.16192112132830647
# Word: signs, Weight: -0.16188052385126445
# Word: pay, Weight: -0.16168259128758625
# Word: talked, Weight: -0.1615487483026289
# Word: shoot, Weight: -0.1613516030411281
# Word: explained, Weight: -0.16081488260355828
# Word: calling, Weight: -0.1605607007818117
# Word: pakistan, Weight: -0.16049505360588628
# Word: venezuela, Weight: -0.16045032719678728
# Word: required, Weight: -0.16023932086558557
# Word: aircraft, Weight: -0.15913245171496457
# Word: district, Weight: -0.15886805995084763
# Word: schools, Weight: -0.15867597069263192
# Word: fast, Weight: -0.15756971359224783
# Word: presumptive, Weight: -0.1575092865553966
# Word: angry, Weight: -0.15750895381966912
# Word: commander, Weight: -0.15748570944823292
# Word: neighborhood, Weight: -0.15590801787337846
# Word: arrests, Weight: -0.15583404573513454
# Word: libya, Weight: -0.1555768104215316
# Word: trip, Weight: -0.15504536842755337
# Word: backing, Weight: -0.1547485405608032
# Word: personally, Weight: -0.15442624122534268
# Word: works, Weight: -0.15440673317672718
# Word: collins, Weight: -0.15363724898491804
# Word: science, Weight: -0.15344328752825134
# Word: cold, Weight: -0.15298850551528484
# Word: courts, Weight: -0.15275194819280857
# Word: 17, Weight: -0.15264799220325145
# Word: qaeda, Weight: -0.1525942706488943
# Word: ongoing, Weight: -0.15228929230953858
# Word: happened, Weight: -0.15224469373207167
# Word: charles, Weight: -0.15163528212224053
# Word: peter, Weight: -0.15158203380284602
# Word: like, Weight: -0.1510998720192477
# Word: proof, Weight: -0.1508468701192726
# Word: sweden, Weight: -0.15039865261809873
# Word: attend, Weight: -0.15007745541220718
# Word: brief, Weight: -0.15006623557955764
# Word: century, Weight: -0.1497414056640804
# Word: pushed, Weight: -0.1496200164339565
# Word: contrast, Weight: -0.14961459143707753
# Word: claims, Weight: -0.14955437667264826
# Word: disgusting, Weight: -0.14935503347118437
# Word: ordered, Weight: -0.1493045974453602
# Word: records, Weight: -0.1492322472319015
# Word: rico, Weight: -0.1489222364500609
# Word: mitch, Weight: -0.14890457487810105
# Word: shame, Weight: -0.14885763583439274
# Word: individual, Weight: -0.1487456385024633
# Word: body, Weight: -0.14855237432236235
# Word: likely, Weight: -0.1484046055435143
# Word: actions, Weight: -0.14840097313766068
# Word: section, Weight: -0.14816268339997807
# Word: reforms, Weight: -0.14773312351740014
# Word: constitutional, Weight: -0.14759484406883705
# Word: division, Weight: -0.14753271366276147
# Word: presented, Weight: -0.14735164759076438
# Word: dossier, Weight: -0.1472957356975531
# Word: johnson, Weight: -0.14726946894046383
# Word: strategy, Weight: -0.14719030904534416
# Word: multiple, Weight: -0.14712995007440619
# Word: advantage, Weight: -0.146773111619959
# Word: deny, Weight: -0.14620674628402902
# Word: simple, Weight: -0.14593340671732255
# Word: facts, Weight: -0.14585238269109077
# Word: 000, Weight: -0.14570192258860906
# Word: sept, Weight: -0.14437098506642215
# Word: shocked, Weight: -0.1442353566921364
# Word: discuss, Weight: -0.14419931393063812
# Word: ethics, Weight: -0.14415953385990604
# Word: opposing, Weight: -0.1440156714565713
# Word: interesting, Weight: -0.14355927617649283
# Word: officials, Weight: -0.14270762430569145
# Word: council, Weight: -0.14266597682637222
# Word: set, Weight: -0.1426468194239124
# Word: effort, Weight: -0.14243660850969242
# Word: regarding, Weight: -0.14220237167553082
# Word: reading, Weight: -0.142076235650281
# Word: congressional, Weight: -0.14193067507855583
# Word: previously, Weight: -0.14180051355059037
# Word: replace, Weight: -0.141696176502274
# Word: usual, Weight: -0.14144709761033253
# Word: consideration, Weight: -0.1414181410209846
# Word: thinking, Weight: -0.14136881731164774
# Word: ministers, Weight: -0.14128047053811335
# Word: total, Weight: -0.1410244680957651
# Word: stood, Weight: -0.14099510153015898
# Word: rating, Weight: -0.1409573901570937
# Word: davis, Weight: -0.14082014330465145
# Word: inside, Weight: -0.14058649272912055
# Word: parents, Weight: -0.140504520559818
# Word: flag, Weight: -0.14016988665743818
# Word: hoping, Weight: -0.13984816260614075
# Word: scheme, Weight: -0.13964200922620146
# Word: iranian, Weight: -0.1396343235457058
# Word: garland, Weight: -0.13932322309804868
# Word: hundreds, Weight: -0.1392291473661133
# Word: ridiculous, Weight: -0.13910799816861547
# Word: corporate, Weight: -0.13890628372921407
# Word: palin, Weight: -0.13852610055470416
# Word: los, Weight: -0.13802950877086528
# Word: critics, Weight: -0.13771722671576828
# Word: ones, Weight: -0.13751360499755344
# Word: mueller, Weight: -0.13740535753170735
# Word: assistant, Weight: -0.1362679497351086
# Word: apart, Weight: -0.13608432097305445
# Word: positions, Weight: -0.13560599431866582
# Word: hatred, Weight: -0.13549211324931726
# Word: waiting, Weight: -0.13529443478821718
# Word: meant, Weight: -0.1352931154761385
# Word: enemy, Weight: -0.13512539569810175
# Word: narrative, Weight: -0.13465586428483176
# Word: school, Weight: -0.13463460555033058
# Word: analysts, Weight: -0.13458915922694256
# Word: tonight, Weight: -0.1345509562640436
# Word: gender, Weight: -0.13423349127152226
# Word: goes, Weight: -0.1340570732209533
# Word: low, Weight: -0.1340550464451662
# Word: vision, Weight: -0.1340042582520348
# Word: message, Weight: -0.13364816331596022
# Word: abe, Weight: -0.13353674462425075
# Word: star, Weight: -0.13317290652476188
# Word: confirmed, Weight: -0.13279636564802474
# Word: stepped, Weight: -0.13229898160695627
# Word: estimated, Weight: -0.13219410861345132
# Word: wish, Weight: -0.13215531968341876
# Word: hostile, Weight: -0.13204718456879866
# Word: currency, Weight: -0.1319441552651759
# Word: campaigns, Weight: -0.13153564951805521
# Word: drugs, Weight: -0.13152900839176235
# Word: favor, Weight: -0.13115312881210206
# Word: confederate, Weight: -0.1311132719981687
# Word: longer, Weight: -0.1309857520874687
# Word: rape, Weight: -0.13086182671053848
# Word: prepared, Weight: -0.13068810056134567
# Word: 32, Weight: -0.130483196850434
# Word: supporting, Weight: -0.12978747710893435
# Word: help, Weight: -0.1295931487853656
# Word: thanks, Weight: -0.12948983546019688
# Word: does, Weight: -0.12910217123547285
# Word: product, Weight: -0.12903618992992585
# Word: pope, Weight: -0.1288629232882046
# Word: standards, Weight: -0.12881824981763645
# Word: citizens, Weight: -0.1287953975287489
# Word: command, Weight: -0.12855351512624624
# Word: dark, Weight: -0.1284138010762401
# Word: initial, Weight: -0.12835451245472126
# Word: asking, Weight: -0.1277357441256712
# Word: organized, Weight: -0.1275006483628786
# Word: camp, Weight: -0.1272130721655952
# Word: legitimate, Weight: -0.12699045271566725
# Word: given, Weight: -0.12675863068270024
# Word: essentially, Weight: -0.12632998211008017
# Word: classified, Weight: -0.1257580675209966
# Word: strong, Weight: -0.12570756524388899
# Word: water, Weight: -0.12499705352761309
# Word: young, Weight: -0.12479357116834483
# Word: supposed, Weight: -0.12446815194325447
# Word: personal, Weight: -0.12445127659061392
# Word: views, Weight: -0.1240447739178413
# Word: travel, Weight: -0.12390834995673133
# Word: mccain, Weight: -0.12368134904895375
# Word: outlets, Weight: -0.12272861157865073
# Word: welfare, Weight: -0.12256915295717169
# Word: democrats, Weight: -0.12227681637657387
# Word: welcomed, Weight: -0.12170219819976161
# Word: purchase, Weight: -0.12142031850311676
# Word: permanent, Weight: -0.12132047855679731
# Word: wanted, Weight: -0.12117989260746154
# Word: lie, Weight: -0.12110211342697602
# Word: canadian, Weight: -0.12100760501096346
# Word: picture, Weight: -0.12081530142518448
# Word: diversity, Weight: -0.12032747340143077
# Word: romney, Weight: -0.12004939936239145
# Word: maryland, Weight: -0.11976015812582265
# Word: enforcement, Weight: -0.119755093652256
# Word: users, Weight: -0.11961653134134836
# Word: policies, Weight: -0.11919870215365491
# Word: aware, Weight: -0.11842541686468047
# Word: power, Weight: -0.11835367940420843
# Word: militia, Weight: -0.11775020457610344
# Word: louisiana, Weight: -0.11746574227224993
# Word: love, Weight: -0.11715155086150708
# Word: innocent, Weight: -0.11712489899799058
# Word: room, Weight: -0.11690988012290177
# Word: benefit, Weight: -0.11610573000342249
# Word: detained, Weight: -0.11515400334792618
# Word: mining, Weight: -0.11485025201181295
# Word: patrol, Weight: -0.11469347832238333
# Word: strange, Weight: -0.11463170668005677
# Word: corporations, Weight: -0.11451866566014154
# Word: notes, Weight: -0.11427279204235213
# Word: charlottesville, Weight: -0.1142457857653037
# Word: lgbt, Weight: -0.1140547015379699
# Word: unconstitutional, Weight: -0.11396342237173623
# Word: advice, Weight: -0.11366877134836725
# Word: pm, Weight: -0.11325513989151645
# Word: minority, Weight: -0.11296926862240807
# Word: southeast, Weight: -0.11288400959368783
# Word: dead, Weight: -0.11277618854898107
# Word: changes, Weight: -0.1126443083813323
# Word: gay, Weight: -0.1125810598923549
# Word: resources, Weight: -0.11247273652001918
# Word: customers, Weight: -0.11239707735920676
# Word: literally, Weight: -0.11228013919232448
# Word: did, Weight: -0.11164157255101076
# Word: generation, Weight: -0.11155444163399714
# Word: 500, Weight: -0.11135012935360371
# Word: 2007, Weight: -0.11106630037723211
# Word: happy, Weight: -0.11083383647875177
# Word: clear, Weight: -0.11016469871150221
# Word: return, Weight: -0.10999844386068007
# Word: bathroom, Weight: -0.10995224477388463
# Word: uncertainty, Weight: -0.10933858356983475
# Word: pushing, Weight: -0.10925460061993679
# Word: relations, Weight: -0.1088056022539981
# Word: intended, Weight: -0.1083642935774519
# Word: photo, Weight: -0.10835783045306104
# Word: customs, Weight: -0.10835392555370058
# Word: screenshot, Weight: -0.10827831191585455
# Word: holds, Weight: -0.10807998855204409
# Word: endorsement, Weight: -0.107903728402787
# Word: profits, Weight: -0.10770307143349729
# Word: talking, Weight: -0.10760061702265034
# Word: 2014, Weight: -0.1075356697077123
# Word: pence, Weight: -0.10749600777469262
# Word: repeated, Weight: -0.10748659053655626
# Word: activists, Weight: -0.10707340255788948
# Word: size, Weight: -0.10682760170611977
# Word: handling, Weight: -0.10669632566354362
# Word: committed, Weight: -0.10658823656611807
# Word: personnel, Weight: -0.10651457389729552
# Word: serving, Weight: -0.10580292307598645
# Word: shift, Weight: -0.10554236479745782
# Word: believe, Weight: -0.10531241972234681
# Word: doubt, Weight: -0.10517123652745577
# Word: save, Weight: -0.10511119746489339
# Word: cop, Weight: -0.10484127641401483
# Word: statements, Weight: -0.10434465193424108
# Word: concern, Weight: -0.10424219357818203
# Word: jeb, Weight: -0.10386312331840689
# Word: confirm, Weight: -0.10374486949723778
# Word: suit, Weight: -0.1036477632690467
# Word: nbc, Weight: -0.10337808222299477
# Word: rex, Weight: -0.10335530900881322
# Word: end, Weight: -0.10330263971399235
# Word: voice, Weight: -0.10329419309357601
# Word: plan, Weight: -0.10327459980713755
# Word: mattis, Weight: -0.10306939492106998
# Word: vladimir, Weight: -0.10297831722899946
# Word: approach, Weight: -0.10294772713460446
# Word: bush, Weight: -0.10262197084236671
# Word: begin, Weight: -0.10247125457850519
# Word: assange, Weight: -0.10234818835764738
# Word: harassment, Weight: -0.10217042042023292
# Word: 18, Weight: -0.10215937935442618
# Word: murder, Weight: -0.10177387740002572
# Word: win, Weight: -0.1014754600219189
# Word: includes, Weight: -0.10121117509779634
# Word: hard, Weight: -0.10091099770165846
# Word: crowd, Weight: -0.10088940603523114
# Word: lobbying, Weight: -0.10082365381058253
# Word: rice, Weight: -0.10065373478731757
# Word: violation, Weight: -0.10060170186930088
# Word: regular, Weight: -0.10020788238823759
# Word: meddling, Weight: -0.10017907098172488
# Word: send, Weight: -0.09986457401131699
# Word: southern, Weight: -0.09959715471735703
# Word: outside, Weight: -0.0994737403522443
# Word: gets, Weight: -0.09923617548201782
# Word: suggest, Weight: -0.0984382014588234
# Word: better, Weight: -0.09808287692960439
# Word: roll, Weight: -0.09730700715440548
# Word: secretary, Weight: -0.09725772795546661
# Word: cyber, Weight: -0.09717424948922322
# Word: point, Weight: -0.09691476194515257
# Word: boiler, Weight: -0.09677507194811666
# Word: willing, Weight: -0.09676416828067089
# Word: society, Weight: -0.09666726340087249
# Word: expansion, Weight: -0.09657559241757471
# Word: decided, Weight: -0.09653481309422046
# Word: existing, Weight: -0.09644055333002788
# Word: march, Weight: -0.09637932009850625
# Word: massachusetts, Weight: -0.09594269866168062
# Word: kushner, Weight: -0.09583162571678816
# Word: truth, Weight: -0.09553718942093428
# Word: unable, Weight: -0.09459809023460444
# Word: chuck, Weight: -0.09425671277711244
# Word: care, Weight: -0.09402313299778134
# Word: function, Weight: -0.09305363032979054
# Word: fighting, Weight: -0.09271234687396898
# Word: hall, Weight: -0.09261406465218007
# Word: shooter, Weight: -0.0925843897643779
# Word: lawyer, Weight: -0.09257179955277753
# Word: start, Weight: -0.09251917846071037
# Word: organization, Weight: -0.09243130287992539
# Word: horrible, Weight: -0.0920561113089376
# Word: vote, Weight: -0.09203028825715179
# Word: vietnam, Weight: -0.09190403597526434
# Word: provides, Weight: -0.0917153025131627
# Word: director, Weight: -0.09170512717363988
# Word: choice, Weight: -0.09167403406561815
# Word: shown, Weight: -0.09131959539449516
# Word: site, Weight: -0.09131290268893771
# Word: pre, Weight: -0.09130657021421083
# Word: 31, Weight: -0.0905970043325352
# Word: actual, Weight: -0.09054000457008006
# Word: global, Weight: -0.0905137374494143
# Word: answer, Weight: -0.0903576288574978
# Word: comey, Weight: -0.09032473682790623
# Word: antifa, Weight: -0.09019587935891459
# Word: book, Weight: -0.090045899475333
# Word: vowed, Weight: -0.08979471950548536
# Word: platform, Weight: -0.0895745442744614
# Word: dinner, Weight: -0.08884372241039658
# Word: hackers, Weight: -0.08884166639836921
# Word: eric, Weight: -0.0887443111137667
# Word: authority, Weight: -0.0886100172148237
# Word: issue, Weight: -0.08855075536551396
# Word: big, Weight: -0.08845303111523867
# Word: euro, Weight: -0.08815937495893106
# Word: exposed, Weight: -0.08804406709800985
# Word: target, Weight: -0.08786171639150657
# Word: business, Weight: -0.08774776365847825
# Word: trade, Weight: -0.08761714173829721
# Word: response, Weight: -0.08701120350520541
# Word: amid, Weight: -0.08696856257376173
# Word: hezbollah, Weight: -0.08679160513229522
# Word: assad, Weight: -0.08670748639485616
# Word: accept, Weight: -0.08648871567927291
# Word: previous, Weight: -0.08635806783764514
# Word: occurred, Weight: -0.0862019494819591
# Word: critical, Weight: -0.08614303248692907
# Word: huge, Weight: -0.08613780434120982
# Word: appeal, Weight: -0.08608919477856111
# Word: pro, Weight: -0.08583719682286223
# Word: suicide, Weight: -0.08582248937248621
# Word: thing, Weight: -0.08579972222632076
# Word: episode, Weight: -0.08572592490463052
# Word: highly, Weight: -0.08519478140448589
# Word: sex, Weight: -0.08506065555581707
# Word: sitting, Weight: -0.08503685494161907
# Word: islamist, Weight: -0.08499004392834497
# Word: concerns, Weight: -0.0849647502527702
# Word: obamacare, Weight: -0.08463215198481541
# Word: anthony, Weight: -0.08458246348323815
# Word: george, Weight: -0.08451532553668606
# Word: chicago, Weight: -0.08424581208654153
# Word: turns, Weight: -0.08365752377707493
# Word: making, Weight: -0.08344762763396603
# Word: interior, Weight: -0.08308626003630731
# Word: writing, Weight: -0.08302964151526163
# Word: list, Weight: -0.08288824528917943
# Word: path, Weight: -0.08278961042054442
# Word: acting, Weight: -0.08274967233891453
# Word: create, Weight: -0.08267395396994742
# Word: unprecedented, Weight: -0.08264862693398639
# Word: words, Weight: -0.08213310128395145
# Word: looks, Weight: -0.0819320756714994
# Word: remain, Weight: -0.08188451832742048
# Word: assistance, Weight: -0.08181351994115965
# Word: january, Weight: -0.08180097415037327
# Word: provisions, Weight: -0.08178881195506296
# Word: arrested, Weight: -0.08149672192202387
# Word: illegal, Weight: -0.08146877806480526
# Word: sound, Weight: -0.0814437575638671
# Word: count, Weight: -0.0812907014104629
# Word: spot, Weight: -0.08102512322973142
# Word: gotten, Weight: -0.08100169207137059
# Word: chris, Weight: -0.08095699706063322
# Word: son, Weight: -0.08092075458422683
# Word: cause, Weight: -0.08087223947697009
# Word: captured, Weight: -0.08083942518469664
# Word: vast, Weight: -0.08080425999111776
# Word: allow, Weight: -0.0806894454330352
# Word: 300, Weight: -0.08063702130597666
# Word: according, Weight: -0.08063374090576297
# Word: interference, Weight: -0.08047275665290396
# Word: san, Weight: -0.08039581865113765
# Word: jerusalem, Weight: -0.08009839877758045
# Word: trouble, Weight: -0.08001162224370827
# Word: biggest, Weight: -0.07976477538562321
# Word: field, Weight: -0.07940306951930182
# Word: values, Weight: -0.07931605832105271
# Word: 2005, Weight: -0.07906089631259841
# Word: linked, Weight: -0.07905942599753957
# Word: try, Weight: -0.0787307890985363
# Word: beautiful, Weight: -0.07863466712419073
# Word: decision, Weight: -0.0785746857092243
# Word: sorry, Weight: -0.07794840717348252
# Word: shootings, Weight: -0.07788041399554507
# Word: borders, Weight: -0.07763081309319281
# Word: forced, Weight: -0.07751785972257089
# Word: survey, Weight: -0.077512590016486
# Word: registration, Weight: -0.07747415747564367
# Word: freedom, Weight: -0.07723257141749616
# Word: richard, Weight: -0.07706508994626632
# Word: members, Weight: -0.07699708020712101
# Word: meetings, Weight: -0.07688505720912997
# Word: analysis, Weight: -0.07668831112842017
# Word: wave, Weight: -0.07628364622203232
# Word: discovered, Weight: -0.0760879701661866
# Word: life, Weight: -0.07595194383889671
# Word: journal, Weight: -0.07582548591627425
# Word: gun, Weight: -0.07580754670493083
# Word: significant, Weight: -0.07572237709460797
# Word: asia, Weight: -0.07501586919467036
# Word: equipment, Weight: -0.0748116377460625
# ...
# Word: accounts, Weight: 0.24362187419040607
# Word: veto, Weight: 0.24419124008558307
# Word: worse, Weight: 0.24456246232098064
# Word: creation, Weight: 0.2446859170589948
# Word: declared, Weight: 0.24486570503438906
# Word: 28, Weight: 0.2454669277360532
# Word: spain, Weight: 0.24557063950906213
# Word: formally, Weight: 0.24629571916576767
# Word: broke, Weight: 0.2468194022501199
# Word: central, Weight: 0.24718761909691617
# Word: adviser, Weight: 0.24755457352770352
# Word: jared, Weight: 0.2480747403976605
# Word: attempts, Weight: 0.2484155344018587
# Word: mentioned, Weight: 0.24947948060232833
# Word: world, Weight: 0.24948352496454887
# Word: gorsuch, Weight: 0.2498706245750721
# Word: madrid, Weight: 0.25061943933573433
# Word: accusations, Weight: 0.25101434453625054
# Word: coast, Weight: 0.25113108484384056
# Word: tom, Weight: 0.2521523459780222
# Word: supremacist, Weight: 0.25219176988556075
# Word: fighters, Weight: 0.2528198141758556
# Word: child, Weight: 0.2532460264940082
# Word: network, Weight: 0.253676835214251
# Word: committee, Weight: 0.25496424134035595
# Word: increase, Weight: 0.2555793400941308
# Word: employment, Weight: 0.2562396169105991
# Word: credibility, Weight: 0.25627306224269986
# Word: dallas, Weight: 0.25659498851574747
# Word: companies, Weight: 0.25664545868987654
# Word: threat, Weight: 0.2574429246836471
# Word: dealing, Weight: 0.25768026889585033
# Word: clean, Weight: 0.25779815261834627
# Word: blocked, Weight: 0.25821302532490326
# Word: neighboring, Weight: 0.2582612047992116
# Word: heads, Weight: 0.25912689221989527
# Word: backed, Weight: 0.25928815703947006
# Word: driver, Weight: 0.2594656098215256
# Word: link, Weight: 0.25976461032929
# Word: race, Weight: 0.260426916961524
# Word: rule, Weight: 0.2611509895063805
# Word: independent, Weight: 0.26126758671426914
# Word: attacks, Weight: 0.2613711345447546
# Word: led, Weight: 0.26210908197699107
# Word: looked, Weight: 0.26238713935705094
# Word: operating, Weight: 0.26292610813144035
# Word: qatar, Weight: 0.26318812151245385
# Word: remained, Weight: 0.26421669693985617
# Word: sees, Weight: 0.26485942602129875
# Word: tour, Weight: 0.2653278816173352
# Word: collapse, Weight: 0.2653710938201818
# Word: requires, Weight: 0.26564376366958914
# Word: nominated, Weight: 0.265666747784046
# Word: protesters, Weight: 0.2657307764170505
# Word: denies, Weight: 0.2660462432388763
# Word: potential, Weight: 0.26635516035063106
# Word: difference, Weight: 0.26696442179969265
# Word: australia, Weight: 0.2670203522924447
# Word: period, Weight: 0.26773684816913684
# Word: rules, Weight: 0.27046769092910206
# Word: agencies, Weight: 0.2707652304910515
# Word: tens, Weight: 0.27092522170654304
# Word: touch, Weight: 0.2713449251087171
# Word: sexual, Weight: 0.2716665018369112
# Word: represented, Weight: 0.272138444697978
# Word: seats, Weight: 0.272213693928359
# Word: firms, Weight: 0.27252163019332165
# Word: rohingya, Weight: 0.272901779497101
# Word: warren, Weight: 0.2731885034031203
# Word: announce, Weight: 0.2736452420743217
# Word: nature, Weight: 0.27414073124842475
# Word: pipeline, Weight: 0.2741883503602652
# Word: italy, Weight: 0.274446246361821
# Word: took, Weight: 0.27500148325390267
# Word: residents, Weight: 0.2750727489062576
# Word: entering, Weight: 0.27560291127660713
# Word: leaving, Weight: 0.2776071484344389
# Word: watch, Weight: 0.27790620282864137
# Word: build, Weight: 0.27828463934409775
# Word: strikes, Weight: 0.27840198312036174
# Word: fail, Weight: 0.27859839708103257
# Word: deliver, Weight: 0.2788310929470771
# Word: nominees, Weight: 0.27884284736500325
# Word: foot, Weight: 0.2788793620529098
# Word: river, Weight: 0.27961344437471974
# Word: giant, Weight: 0.28042841237142463
# Word: requirements, Weight: 0.28114161279912325
# Word: japan, Weight: 0.2815909436608911
# Word: businessman, Weight: 0.2828011545929723
# Word: preparing, Weight: 0.2835684075774506
# Word: judicial, Weight: 0.2835763326061388
# Word: van, Weight: 0.28482483102991085
# Word: systems, Weight: 0.28496130063344677
# Word: britain, Weight: 0.2861269706119624
# Word: center, Weight: 0.28694480750562984
# Word: bloc, Weight: 0.28750384042732036
# Word: criticized, Weight: 0.28846077151278376
# Word: firing, Weight: 0.2896708695720467
# Word: week, Weight: 0.29024618283216375
# Word: come, Weight: 0.29050624390019447
# Word: changed, Weight: 0.2909146473855843
# Word: aid, Weight: 0.29136108846136566
# Word: failure, Weight: 0.2914717924625192
# Word: airport, Weight: 0.29200161784411643
# Word: nearby, Weight: 0.2939031437157484
# Word: enemies, Weight: 0.2942540541919639
# Word: dispute, Weight: 0.2945310174692814
# Word: bomb, Weight: 0.29462885932774596
# Word: corker, Weight: 0.29699112895162305
# Word: beijing, Weight: 0.29740784361630906
# Word: debt, Weight: 0.2993286015302888
# Word: immediate, Weight: 0.29975229163760037
# Word: retired, Weight: 0.30034666116513564
# Word: potus, Weight: 0.3011905690897414
# Word: career, Weight: 0.3014653324818013
# Word: red, Weight: 0.3017643842290992
# Word: conference, Weight: 0.3019901044460634
# Word: dangerous, Weight: 0.30242258599839
# Word: mosque, Weight: 0.3033612452947276
# Word: regulatory, Weight: 0.30441350247238275
# Word: options, Weight: 0.3051740097635218
# Word: tank, Weight: 0.3054206780081147
# Word: votes, Weight: 0.3055330342075166
# Word: takes, Weight: 0.30593980170823554
# Word: halt, Weight: 0.3075725579482432
# Word: thinks, Weight: 0.30887041227848855
# Word: seeing, Weight: 0.30990261946469033
# Word: conclusion, Weight: 0.30993045768567246
# Word: association, Weight: 0.3106545519029131
# Word: orlando, Weight: 0.3106823475646988
# Word: bilateral, Weight: 0.31150997572618955
# Word: 48, Weight: 0.3116171805778666
# Word: turkey, Weight: 0.3139969335186729
# Word: display, Weight: 0.3148202310075909
# Word: michelle, Weight: 0.3150076096069028
# Word: fresh, Weight: 0.31678018896111515
# Word: write, Weight: 0.31748478702363686
# Word: shi, Weight: 0.3177711096551777
# Word: eastern, Weight: 0.31859382878960363
# Word: gold, Weight: 0.3189939387724387
# Word: pruitt, Weight: 0.3190796490172909
# Word: gained, Weight: 0.3196222614955434
# Word: presence, Weight: 0.3200633722192905
# Word: tv, Weight: 0.3206724492818314
# Word: phase, Weight: 0.3207061129626789
# Word: test, Weight: 0.32130341336976986
# Word: leader, Weight: 0.3213038824056016
# Word: chamber, Weight: 0.32176479815708375
# Word: killing, Weight: 0.32242077449898787
# Word: protected, Weight: 0.322982565261669
# Word: region, Weight: 0.32369756425605406
# Word: killed, Weight: 0.3237865280994928
# Word: restrictions, Weight: 0.3238444352225409
# Word: strongly, Weight: 0.3239615021265364
# Word: afghanistan, Weight: 0.32440969093295224
# Word: important, Weight: 0.32472249088375515
# Word: parts, Weight: 0.3252375361284734
# Word: allegations, Weight: 0.3253735675375226
# Word: seen, Weight: 0.3265516270424337
# Word: 20, Weight: 0.3274167959913035
# Word: journalists, Weight: 0.3281312665169569
# Word: treated, Weight: 0.32843579790811794
# Word: banned, Weight: 0.32858245456996416
# Word: ted, Weight: 0.3296968102388944
# Word: overall, Weight: 0.33045348861677054
# Word: heard, Weight: 0.33210922691666356
# Word: nominating, Weight: 0.33249918401722617
# Word: gives, Weight: 0.3325850647540296
# Word: noting, Weight: 0.33266168202702384
# Word: afghan, Weight: 0.33288623743065654
# Word: impossible, Weight: 0.3331502606519613
# Word: reach, Weight: 0.3382113344647218
# Word: needed, Weight: 0.33916828430481955
# Word: beirut, Weight: 0.3398678048238908
# Word: recognized, Weight: 0.34092235409042126
# Word: speech, Weight: 0.34136184924542423
# Word: firm, Weight: 0.3423934175878155
# Word: separate, Weight: 0.3426525030977824
# Word: posted, Weight: 0.34267852783428143
# Word: sign, Weight: 0.34368023243575974
# Word: promote, Weight: 0.34413869847910217
# Word: playing, Weight: 0.34444284230925615
# Word: convention, Weight: 0.34454639174397395
# Word: agency, Weight: 0.3450382377470452
# Word: shot, Weight: 0.3450569444647744
# Word: track, Weight: 0.3451550272562445
# Word: candidacy, Weight: 0.3467691527672168
# Word: additional, Weight: 0.3467758393686622
# Word: everybody, Weight: 0.34722975014487123
# Word: prosecutor, Weight: 0.3487812920022736
# Word: easy, Weight: 0.34933397472877403
# Word: say, Weight: 0.34934784562364196
# Word: progress, Weight: 0.3496458524282384
# Word: levels, Weight: 0.350166410228977
# Word: oct, Weight: 0.3503158662801854
# Word: resignation, Weight: 0.35051816312166173
# Word: militant, Weight: 0.3526452273818251
# Word: based, Weight: 0.3528618388784367
# Word: province, Weight: 0.3529331536224431
# Word: kurdish, Weight: 0.35473025510475226
# Word: anger, Weight: 0.35496612131046146
# Word: spokesman, Weight: 0.3553552506603097
# Word: purpose, Weight: 0.35616999733211363
# Word: branch, Weight: 0.35658731759258194
# Word: deportation, Weight: 0.3585759000287821
# Word: helped, Weight: 0.3595065471282217
# Word: store, Weight: 0.3603267589337566
# Word: 35, Weight: 0.3604189184178549
# Word: spoken, Weight: 0.3607095760843578
# Word: died, Weight: 0.36135804088158185
# Word: ahead, Weight: 0.36178768304322007
# Word: sector, Weight: 0.3622781469239842
# Word: philadelphia, Weight: 0.36339403825982586
# Word: draw, Weight: 0.36486101284216693
# Word: drop, Weight: 0.3663853412293506
# Word: hariri, Weight: 0.36645842047976346
# Word: buildings, Weight: 0.3680698505356218
# Word: angela, Weight: 0.3714156009011148
# Word: failing, Weight: 0.3730614797534964
# Word: especially, Weight: 0.3735009504047777
# Word: suspect, Weight: 0.37425585150383656
# Word: capital, Weight: 0.3753618060622731
# Word: delivered, Weight: 0.37644441283611496
# Word: rnc, Weight: 0.3767828879566549
# Word: fleeing, Weight: 0.3768468320570652
# Word: staff, Weight: 0.37845979033459287
# Word: sort, Weight: 0.37859169752090155
# Word: finding, Weight: 0.37883293545286967
# Word: camps, Weight: 0.37893057698439747
# Word: greatest, Weight: 0.3790048515623101
# Word: testimony, Weight: 0.38071460243928573
# Word: communities, Weight: 0.3807474754991252
# Word: energy, Weight: 0.3821788120920787
# Word: 200, Weight: 0.3828878600232377
# Word: today, Weight: 0.3836046585695594
# Word: management, Weight: 0.3843067402414614
# Word: challenges, Weight: 0.38646835884868547
# Word: healthcare, Weight: 0.39025751696744815
# Word: myanmar, Weight: 0.3907369443033958
# Word: produced, Weight: 0.3917125006379282
# Word: ministry, Weight: 0.39291794251509177
# Word: square, Weight: 0.39373124797937703
# Word: paris, Weight: 0.39409064173126285
# Word: tension, Weight: 0.395492315138473
# Word: mean, Weight: 0.396491420169238
# Word: visa, Weight: 0.3966224528271275
# Word: tax, Weight: 0.4001218401865416
# Word: newspaper, Weight: 0.40020306055882937
# Word: safety, Weight: 0.4008757722169049
# Word: seriously, Weight: 0.4036664888349243
# Word: space, Weight: 0.4044429868820496
# Word: ireland, Weight: 0.404775240657742
# Word: quickly, Weight: 0.40526049503374856
# Word: sanders, Weight: 0.4068906626567206
# Word: leaves, Weight: 0.4082620784644247
# Word: computer, Weight: 0.4096121061441179
# Word: mainly, Weight: 0.40966190572064864
# Word: despite, Weight: 0.4102005482856457
# Word: republican, Weight: 0.4105148542080527
# Word: closed, Weight: 0.4130156977373771
# Word: appropriate, Weight: 0.4134427435840169
# Word: african, Weight: 0.41351800892100155
# Word: rescue, Weight: 0.4166593833553476
# Word: sentenced, Weight: 0.4185145869819279
# Word: view, Weight: 0.420065563776831
# Word: treasury, Weight: 0.4205722481487757
# Word: guns, Weight: 0.42074968173269733
# Word: briefing, Weight: 0.4224195348845539
# Word: adam, Weight: 0.4232183460003191
# Word: illinois, Weight: 0.42684202920616343
# Word: dollar, Weight: 0.4274784700357136
# Word: urged, Weight: 0.4295454754133029
# Word: vermont, Weight: 0.43060857059197777
# Word: probe, Weight: 0.4308742743108352
# Word: uranium, Weight: 0.4318542093641109
# Word: vehicles, Weight: 0.43223405882457006
# Word: crackdown, Weight: 0.4324512273908531
# Word: bay, Weight: 0.4338951326621221
# Word: communications, Weight: 0.434555453325191
# Word: nafta, Weight: 0.4351337588922613
# Word: providing, Weight: 0.4355822056350775
# Word: macron, Weight: 0.43841033692994474
# Word: catalan, Weight: 0.4401698253626888
# Word: egypt, Weight: 0.44035399906441697
# Word: moves, Weight: 0.4409328794712472
# Word: judges, Weight: 0.44094054840455693
# Word: built, Weight: 0.44145878669936134
# Word: deficit, Weight: 0.44286511836262
# Word: donald, Weight: 0.44484274973034665
# Word: fiscal, Weight: 0.444935714332011
# Word: growing, Weight: 0.4465969140147621
# Word: wide, Weight: 0.447764746003127
# Word: wrote, Weight: 0.44800593223554686
# Word: jan, Weight: 0.4482455056962084
# Word: role, Weight: 0.45424068650022914
# Word: moscow, Weight: 0.4545816273622071
# Word: concerned, Weight: 0.45458884247773756
# Word: league, Weight: 0.45468588966259793
# Word: twice, Weight: 0.45527045845458575
# Word: theory, Weight: 0.4558603436042659
# Word: wrong, Weight: 0.4573583069836398
# Word: fully, Weight: 0.4588994490693116
# Word: rock, Weight: 0.459041950309694
# Word: boost, Weight: 0.4596359024886706
# Word: agreed, Weight: 0.4620149600098125
# Word: cabinet, Weight: 0.4639845795077191
# Word: corruption, Weight: 0.46464615689496075
# Word: golf, Weight: 0.46565610217992626
# Word: contest, Weight: 0.4659070666263591
# Word: ipsos, Weight: 0.4661909682163321
# Word: broader, Weight: 0.46862932214442377
# Word: stated, Weight: 0.4692021709051586
# Word: expressed, Weight: 0.47180831389734856
# Word: require, Weight: 0.4744647272331126
# Word: smaller, Weight: 0.4781650390647283
# Word: lawmaker, Weight: 0.4832323403365144
# Word: barack, Weight: 0.49070484726280544
# Word: crimes, Weight: 0.49573377569615096
# Word: representatives, Weight: 0.49598045406035085
# Word: reporters, Weight: 0.49673295693620234
# Word: fuel, Weight: 0.49824994520807087
# Word: peace, Weight: 0.4997760226388145
# Word: representing, Weight: 0.4999224499083642
# Word: ally, Weight: 0.5012535060726306
# Word: tehran, Weight: 0.5015343614996719
# Word: ankara, Weight: 0.5029623757088142
# Word: value, Weight: 0.5047606021119109
# Word: kurdistan, Weight: 0.5054363885990658
# Word: opposition, Weight: 0.5069955048800946
# Word: praised, Weight: 0.5113585115163629
# Word: broad, Weight: 0.5133858028597924
# Word: fifth, Weight: 0.5133922358904134
# Word: texas, Weight: 0.5139960761019029
# Word: ethnic, Weight: 0.5148541700705573
# Word: overhaul, Weight: 0.5154627719910942
# Word: hear, Weight: 0.517366027461837
# Word: summit, Weight: 0.5202865083913778
# Word: declined, Weight: 0.5226541505408455
# Word: age, Weight: 0.5230854493406216
# Word: opinions, Weight: 0.5366767656087829
# Word: independently, Weight: 0.5369072717438347
# Word: lawsuit, Weight: 0.5422459571214343
# Word: opponents, Weight: 0.5444091034438733
# Word: brought, Weight: 0.5461906321819235
# Word: fans, Weight: 0.5488892872904669
# Word: proposals, Weight: 0.5660180017005555
# Word: berlin, Weight: 0.5690176281395424
# Word: tech, Weight: 0.5715298860550991
# Word: lawyers, Weight: 0.5760659518699169
# Word: www, Weight: 0.5766865076679006
# Word: parliament, Weight: 0.6005530362496445
# Word: forum, Weight: 0.6047858753806359
# Word: rejected, Weight: 0.6060007475011827
# Word: risks, Weight: 0.6071417030753359
# Word: serve, Weight: 0.6073556344267668
# Word: questions, Weight: 0.6077566231004031
# Word: conditions, Weight: 0.611642997337511
# Word: parliamentary, Weight: 0.6286389452445738
# Word: showing, Weight: 0.6583034098454174
# Word: visiting, Weight: 0.6586440056664189
# Word: mugabe, Weight: 0.6639375055816408
# Word: quoted, Weight: 0.667974217156582
# Word: statement, Weight: 0.6781143009520121
# Word: pacific, Weight: 0.6884463989273604
# Word: carried, Weight: 0.6914855487000362
# Word: fine, Weight: 0.7093779355285796
# Word: referring, Weight: 0.7114577596981954
# Word: wars, Weight: 0.7149415863326319
# Word: sarah, Weight: 0.7513478297947821
# Word: citing, Weight: 0.7529195010717081
# Word: shouldn, Weight: 0.7689760081894115
# Word: bit, Weight: 0.7756064125495954
# Word: london, Weight: 0.775711514674858
# Word: monday, Weight: 0.8042050489172713
# Word: friday, Weight: 0.8544935786979362
# Word: available, Weight: 0.8574193907077505
# Word: trying, Weight: 0.8600151119432656
# Word: nov, Weight: 1.0117662589134053
# Word: throw, Weight: 1.0449060417922102
# Word: website, Weight: 1.1525687825984625
# Word: km, Weight: 1.1612977150950752

# %%
df_1 = pd.read_csv('../data/evaluation.csv', sep=';')
df_2 = pd.read_csv('../data/test.csv', sep=';')
df_3 = pd.read_csv('../data/train.csv', sep=';')

new_df = pd.concat([df_1, df_2, df_3], ignore_index=True)
new_df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Sanders back in U.S. Senate, blasts 'coloniali...
# 1           1  Kremlin: Syria peoples' congress being 'active...
# 2           2   Oregon Cop Convicted Of Shattering Biker’s Co...
# 3           3   Twitter Erupts With Glee Over #CruzSexScandal...
# 4           4  MUST WATCH VIDEO: Obama Tries To Trash Trump B...
#
#                                                 text  label
# 0  WASHINGTON (Reuters) - Democratic U.S. preside...      1
# 1  MOSCOW (Reuters) - A proposal to convene a con...      1
# 2  In a baffling fit of rage, an Oregon State Pol...      0
# 3  The last thing any politician running for the ...      0
# 4  This is too good to miss! Mr. Teleprompter did...      0

# %%
# new_df['cleaned_text'] = new_df['text'].apply(clean_text)
# new_df['cleaned_title'] = new_df['title'].apply(clean_text)
# new_df['truncated_text'] = new_df['cleaned_text'].apply(lambda x: ' '.join(x.split()[:25]))

# %%
new_df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Sanders back in U.S. Senate, blasts 'coloniali...
# 1           1  Kremlin: Syria peoples' congress being 'active...
# 2           2   Oregon Cop Convicted Of Shattering Biker’s Co...
# 3           3   Twitter Erupts With Glee Over #CruzSexScandal...
# 4           4  MUST WATCH VIDEO: Obama Tries To Trash Trump B...
#
#                                                 text  label
# 0  WASHINGTON (Reuters) - Democratic U.S. preside...      1
# 1  MOSCOW (Reuters) - A proposal to convene a con...      1
# 2  In a baffling fit of rage, an Oregon State Pol...      0
# 3  The last thing any politician running for the ...      0
# 4  This is too good to miss! Mr. Teleprompter did...      0

# %%
new_y = new_df['label']

# %%
# # Fit the vectorizer and transform the cleaned text
vectorizer = CountVectorizer(stop_words='english', max_features=3000)
X = vectorizer.fit_transform(new_df['text'])

# # Get the feature names to understand what words are included
feature_names = vectorizer.get_feature_names_out()

print(X.shape)
# Out:
# (40587, 3000)

# %% [markdown]
# ## Model performance on the other dataset

# %%
X, _, y, _ = train_test_split(X, new_y, test_size=0.01, random_state=42)
print(X.shape)
print(y.shape)
# Check accuracy on the test set
test_accuracy = svm_classifier.score(X, y)
print(f"Accuracy: {test_accuracy:.2%}")

# Predict the labels for the test set
y_pred = svm_classifier.predict(X)

# Generate a classification report
report = classification_report(y, y_pred, target_names=['Fake', 'Real'])
print(report)

# Print confusion matrix
conf_matrix = confusion_matrix(y, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# (40181, 3000)
# (40181,)
# Accuracy: 52.54%
#               precision    recall  f1-score   support
#
#         Fake       0.49      0.88      0.63     18468
#         Real       0.68      0.23      0.34     21713
#
#     accuracy                           0.53     40181
#    macro avg       0.59      0.55      0.49     40181
# weighted avg       0.59      0.53      0.47     40181
#
# Confusion Matrix:
#  [[16163  2305]
#  [16764  4949]]
